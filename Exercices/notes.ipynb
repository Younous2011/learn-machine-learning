# %% [markdown]
# # Chapitre 1 : Structure matricièle

# %%
import pandas as pd
import numpy as np
import random

# %%
def random_notes():
    return random.randint(0, 20)

# %%
# On définit les prénoms des élèves
prenoms = ["Caroline", "Youssef", "Micheal", "Badr", "Chady", "Younous", "Ismael", "Eymen", "Aslam", "Saleh", "Soufiane", "Sanaa"]
# On définit les matières
matieres = ["Maths", "Français", "Histoire-géo", "Physique-Chimie", "SVT", "Anglais"]
# On initialise la liste des notes de tous les élèves
notes = []

# On itère sur tous les élèves
for i  in range(12): 
    # On initialise une liste vide pour chaque élève
    notes_eleve = []
    # Pour chaque élève, on itère sur toutes les matières
    for j in range(6):
        # Pour chaque élève et pour chaque matière, on rajoute une notye aléatoire à la liste des notes d'un élève
        notes_eleve.append(random_notes())
    # On rajoute la liste des notes globales
    notes.append(notes_eleve)
# On affiche les notes
print(notes)
# Out:
# [[0, 4, 18, 3, 11, 13], [2, 6, 17, 0, 9, 4], [18, 2, 0, 11, 18, 9], [6, 16, 9, 3, 2, 12], [4, 15, 4, 12, 16, 1], [10, 12, 14, 1, 14, 1], [16, 15, 1, 6, 5, 9], [18, 16, 2, 8, 10, 8], [12, 16, 4, 8, 17, 4], [15, 14, 12, 0, 6, 8], [7, 0, 9, 10, 11, 10], [14, 0, 5, 5, 19, 12]]

# %%
df = pd.DataFrame(notes, columns=matieres, index=prenoms)

# %%
df
# Out:
#           Maths  Français  Histoire-géo  Physique-Chimie  SVT  Anglais
# Caroline      0         4            18                3   11       13
# Youssef       2         6            17                0    9        4
# Micheal      18         2             0               11   18        9
# Badr          6        16             9                3    2       12
# Chady         4        15             4               12   16        1
# Younous      10        12            14                1   14        1
# Ismael       16        15             1                6    5        9
# Eymen        18        16             2                8   10        8
# Aslam        12        16             4                8   17        4
# Saleh        15        14            12                0    6        8
# Soufiane      7         0             9               10   11       10
# Sanaa        14         0             5                5   19       12

# %%
df.loc["Younous", "Maths"] = 20
df
# Out:
#           Maths  Français  Histoire-géo  Physique-Chimie  SVT  Anglais
# Caroline      0         4            18                3   11       13
# Youssef       2         6            17                0    9        4
# Micheal      18         2             0               11   18        9
# Badr          6        16             9                3    2       12
# Chady         4        15             4               12   16        1
# Younous      20        12            14                1   14        1
# Ismael       16        15             1                6    5        9
# Eymen        18        16             2                8   10        8
# Aslam        12        16             4                8   17        4
# Saleh        15        14            12                0    6        8
# Soufiane      7         0             9               10   11       10
# Sanaa        14         0             5                5   19       12

# %%
df["Total"] = df["Maths"] + df["Français"] + df["Histoire-géo"] + df["Physique-Chimie"] + df["SVT"] + df["Anglais"]

# %%
df["Moyenne"] = df["Total"] / 6

# %%
df[matieres]
# Out:
#           Maths  Français  Histoire-géo  Physique-Chimie  SVT  Anglais
# Caroline      0         4            18                3   11       13
# Youssef       2         6            17                0    9        4
# Micheal      18         2             0               11   18        9
# Badr          6        16             9                3    2       12
# Chady         4        15             4               12   16        1
# Younous      20        12            14                1   14        1
# Ismael       16        15             1                6    5        9
# Eymen        18        16             2                8   10        8
# Aslam        12        16             4                8   17        4
# Saleh        15        14            12                0    6        8
# Soufiane      7         0             9               10   11       10
# Sanaa        14         0             5                5   19       12

# %%
df["mean"] = df[matieres].mean(axis=1)

# %%
df
# Out:
#           Maths  Français  Histoire-géo  Physique-Chimie  SVT  Anglais  Total  \
# Caroline      0         4            18                3   11       13     49
# Youssef       2         6            17                0    9        4     38
# Micheal      18         2             0               11   18        9     58
# Badr          6        16             9                3    2       12     48
# Chady         4        15             4               12   16        1     52
# Younous      20        12            14                1   14        1     62
# Ismael       16        15             1                6    5        9     52
# Eymen        18        16             2                8   10        8     62
# Aslam        12        16             4                8   17        4     61
# Saleh        15        14            12                0    6        8     55
# Soufiane      7         0             9               10   11       10     47
# Sanaa        14         0             5                5   19       12     55
#
#             Moyenne       mean
# Caroline   8.166667   8.166667
# Youssef    6.333333   6.333333
# Micheal    9.666667   9.666667
# Badr       8.000000   8.000000
# Chady      8.666667   8.666667
# Younous   10.333333  10.333333
# Ismael     8.666667   8.666667
# Eymen     10.333333  10.333333
# Aslam     10.166667  10.166667
# Saleh      9.166667   9.166667
# Soufiane   7.833333   7.833333
# Sanaa      9.166667   9.166667

# %%
maskSup = df["mean"] >= 10
df[maskSup]
# Out:
#          Maths  Français  Histoire-géo  Physique-Chimie  SVT  Anglais  Total  \
# Younous     20        12            14                1   14        1     62
# Eymen       18        16             2                8   10        8     62
# Aslam       12        16             4                8   17        4     61
#
#            Moyenne       mean
# Younous  10.333333  10.333333
# Eymen    10.333333  10.333333
# Aslam    10.166667  10.166667

# %%
maskInf = df["mean"] < 10
df[maskInf]
# Out:
#           Maths  Français  Histoire-géo  Physique-Chimie  SVT  Anglais  Total  \
# Caroline      0         4            18                3   11       13     49
# Youssef       2         6            17                0    9        4     38
# Micheal      18         2             0               11   18        9     58
# Badr          6        16             9                3    2       12     48
# Chady         4        15             4               12   16        1     52
# Ismael       16        15             1                6    5        9     52
# Saleh        15        14            12                0    6        8     55
# Soufiane      7         0             9               10   11       10     47
# Sanaa        14         0             5                5   19       12     55
#
#            Moyenne      mean
# Caroline  8.166667  8.166667
# Youssef   6.333333  6.333333
# Micheal   9.666667  9.666667
# Badr      8.000000  8.000000
# Chady     8.666667  8.666667
# Ismael    8.666667  8.666667
# Saleh     9.166667  9.166667
# Soufiane  7.833333  7.833333
# Sanaa     9.166667  9.166667

# %% [markdown]
# # Chapitre 2 : Structure en tuple

# %%
"""
    notes = [
        ["Caroline", "Maths", 18],
        ["Caroline", "Français", 12],
        ...,
        ["Sanaa", "Anglais", 12] 
    ]
"""
