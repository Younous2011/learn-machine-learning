# %% [markdown]
# # Chapitre 1 : Structure matricièle

# %%
import pandas as pd
import numpy as np
import random
# Out:
# /home/younous/.local/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
def random_notes():
    return random.randint(0, 20)

# %%
# On définit les prénoms des élèves
prenoms = ["Caroline", "Youssef", "Micheal", "Badr", "Chady", "Ismael", "Eymen", "Aslam", "Saleh", "Soufiane", "Sanaa"]
prenomsY = prenoms + ["Younous"]
# On définit les matières
matieres = ["Maths", "Français", "Histoire-géo", "Physique-Chimie", "SVT", "Anglais"]
# On initialise la liste des notes de tous les élèves
notes = []

# On itère sur tous les élèves
for i  in range(11): 
    # On initialise une liste vide pour chaque élève
    notes_eleve = []
    # Pour chaque élève, on itère sur toutes les matières
    for j in range(6):
        # Pour chaque élève et pour chaque matière, on rajoute une notye aléatoire à la liste des notes d'un élève
        notes_eleve.append(random_notes())
    # On rajoute la liste des notes globales
    notes.append(notes_eleve)
# On rajoute les notes de Younous
notes.append([18, 20, 20, 20, 20, 100])
# On affiche les notes
print(notes)
# Out:
# [[19, 19, 0, 0, 4, 8], [19, 15, 20, 15, 4, 13], [2, 0, 6, 10, 2, 4], [7, 10, 5, 7, 8, 16], [8, 4, 9, 0, 20, 16], [0, 16, 6, 7, 3, 1], [15, 20, 12, 13, 9, 2], [20, 6, 5, 1, 10, 11], [2, 18, 1, 16, 10, 12], [4, 6, 9, 19, 19, 20], [14, 7, 5, 17, 18, 15], [18, 20, 20, 20, 20, 100]]

# %%
df = pd.DataFrame(notes, columns=matieres, index=prenomsY)

# %%
df
# Out:
#           Maths  Français  Histoire-géo  Physique-Chimie  SVT  Anglais
# Caroline     19        19             0                0    4        8
# Youssef      19        15            20               15    4       13
# Micheal       2         0             6               10    2        4
# Badr          7        10             5                7    8       16
# Chady         8         4             9                0   20       16
# Ismael        0        16             6                7    3        1
# Eymen        15        20            12               13    9        2
# Aslam        20         6             5                1   10       11
# Saleh         2        18             1               16   10       12
# Soufiane      4         6             9               19   19       20
# Sanaa        14         7             5               17   18       15
# Younous      18        20            20               20   20      100

# %%
df.loc["Younous", "Maths"] = 20
df
# Out:
#           Maths  Français  Histoire-géo  Physique-Chimie  SVT  Anglais
# Caroline     19        19             0                0    4        8
# Youssef      19        15            20               15    4       13
# Micheal       2         0             6               10    2        4
# Badr          7        10             5                7    8       16
# Chady         8         4             9                0   20       16
# Ismael        0        16             6                7    3        1
# Eymen        15        20            12               13    9        2
# Aslam        20         6             5                1   10       11
# Saleh         2        18             1               16   10       12
# Soufiane      4         6             9               19   19       20
# Sanaa        14         7             5               17   18       15
# Younous      20        20            20               20   20      100

# %%
df["Total"] = df["Maths"] + df["Français"] + df["Histoire-géo"] + df["Physique-Chimie"] + df["SVT"] + df["Anglais"]

# %%
df["Moyenne"] = df["Total"] / 6

# %%
df[matieres]
# Out:
#           Maths  Français  Histoire-géo  Physique-Chimie  SVT  Anglais
# Caroline     19        19             0                0    4        8
# Youssef      19        15            20               15    4       13
# Micheal       2         0             6               10    2        4
# Badr          7        10             5                7    8       16
# Chady         8         4             9                0   20       16
# Ismael        0        16             6                7    3        1
# Eymen        15        20            12               13    9        2
# Aslam        20         6             5                1   10       11
# Saleh         2        18             1               16   10       12
# Soufiane      4         6             9               19   19       20
# Sanaa        14         7             5               17   18       15
# Younous      20        20            20               20   20      100

# %%
df["mean"] = df[matieres].mean(axis=1)

# %%
df
# Out:
#           Maths  Français  Histoire-géo  Physique-Chimie  SVT  Anglais  Total  \
# Caroline     19        19             0                0    4        8     50
# Youssef      19        15            20               15    4       13     86
# Micheal       2         0             6               10    2        4     24
# Badr          7        10             5                7    8       16     53
# Chady         8         4             9                0   20       16     57
# Ismael        0        16             6                7    3        1     33
# Eymen        15        20            12               13    9        2     71
# Aslam        20         6             5                1   10       11     53
# Saleh         2        18             1               16   10       12     59
# Soufiane      4         6             9               19   19       20     77
# Sanaa        14         7             5               17   18       15     76
# ...

# %%
maskSup = df["mean"] >= 10
df[maskSup]
# Out:
#           Maths  Français  Histoire-géo  Physique-Chimie  SVT  Anglais  Total  \
# Youssef      19        15            20               15    4       13     86
# Eymen        15        20            12               13    9        2     71
# Soufiane      4         6             9               19   19       20     77
# Sanaa        14         7             5               17   18       15     76
# Younous      20        20            20               20   20      100    200
#
#             Moyenne       mean
# Youssef   14.333333  14.333333
# Eymen     11.833333  11.833333
# Soufiane  12.833333  12.833333
# Sanaa     12.666667  12.666667
# Younous   33.333333  33.333333

# %%
maskInf = df["mean"] < 10
df[maskInf]
# Out:
#           Maths  Français  Histoire-géo  Physique-Chimie  SVT  Anglais  Total  \
# Caroline     19        19             0                0    4        8     50
# Micheal       2         0             6               10    2        4     24
# Badr          7        10             5                7    8       16     53
# Chady         8         4             9                0   20       16     57
# Ismael        0        16             6                7    3        1     33
# Aslam        20         6             5                1   10       11     53
# Saleh         2        18             1               16   10       12     59
#
#            Moyenne      mean
# Caroline  8.333333  8.333333
# Micheal   4.000000  4.000000
# Badr      8.833333  8.833333
# Chady     9.500000  9.500000
# Ismael    5.500000  5.500000
# Aslam     8.833333  8.833333
# Saleh     9.833333  9.833333

# %% [markdown]
# # Chapitre 2 : Structure en tuple

# %%
"""
    notes = [
        ["Caroline", "Maths", 18],
        ["Caroline", "Français", 12],
        ...,
        ["Sanaa", "Anglais", 12] 
    ]
"""
# Out:
# '\n    notes = [\n        ["Caroline", "Maths", 18],\n        ["Caroline", "Français", 12],\n        ...,\n        ["Sanaa", "Anglais", 12] \n    ]\n'

# %%
notes = []
for prenom in prenoms:
    for matiere in matieres:
        notes.append([prenom, matiere, random_notes()])

notes.append(["Younous", "Maths", 21])
notes.append(["Younous", "Français", 19])
notes.append(["Younous", "Histoire-géo", 19.5])
notes.append(["Younous", "Physique-Chimie", 17.75])
notes.append(["Younous", "SVT", 19])
notes.append(["Younous", "Anglais", 19.99])
notes
# Out:
# [['Caroline', 'Maths', 8],
#  ['Caroline', 'Français', 19],
#  ['Caroline', 'Histoire-géo', 18],
#  ['Caroline', 'Physique-Chimie', 18],
#  ['Caroline', 'SVT', 19],
#  ['Caroline', 'Anglais', 0],
#  ['Youssef', 'Maths', 20],
#  ['Youssef', 'Français', 5],
#  ['Youssef', 'Histoire-géo', 7],
#  ['Youssef', 'Physique-Chimie', 6],
#  ['Youssef', 'SVT', 11],
#  ['Youssef', 'Anglais', 10],
#  ['Micheal', 'Maths', 3],
#  ['Micheal', 'Français', 5],
#  ['Micheal', 'Histoire-géo', 17],
#  ['Micheal', 'Physique-Chimie', 11],
#  ['Micheal', 'SVT', 5],
#  ['Micheal', 'Anglais', 11],
#  ['Badr', 'Maths', 13],
#  ['Badr', 'Français', 7],
#  ['Badr', 'Histoire-géo', 9],
#  ['Badr', 'Physique-Chimie', 8],
#  ['Badr', 'SVT', 20],
#  ['Badr', 'Anglais', 10],
#  ['Chady', 'Maths', 4],
#  ['Chady', 'Français', 12],
#  ['Chady', 'Histoire-géo', 19],
#  ['Chady', 'Physique-Chimie', 16],
#  ['Chady', 'SVT', 0],
#  ['Chady', 'Anglais', 3],
#  ['Ismael', 'Maths', 4],
#  ['Ismael', 'Français', 12],
# ...

# %%
df = pd.DataFrame(notes, columns=["Prenom", "Matière", "Note"])
df.head()
# Out:
#      Prenom          Matière  Note
# 0  Caroline            Maths   8.0
# 1  Caroline         Français  19.0
# 2  Caroline     Histoire-géo  18.0
# 3  Caroline  Physique-Chimie  18.0
# 4  Caroline              SVT  19.0

# %%
mask = df["Prenom"] == "Caroline"
mask
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 67    False
# 68    False
# 69    False
# 70    False
# 71    False
# Name: Prenom, Length: 72, dtype: bool

# %%
df_caroline = df[mask]
df_caroline
# Out:
#      Prenom          Matière  Note
# 0  Caroline            Maths   8.0
# 1  Caroline         Français  19.0
# 2  Caroline     Histoire-géo  18.0
# 3  Caroline  Physique-Chimie  18.0
# 4  Caroline              SVT  19.0
# 5  Caroline          Anglais   0.0

# %%
df_caroline["Note"].mean()
# Out:
# 13.666666666666666

# %%
df.groupby("Prenom").mean()
# Out:
#                Note
# Prenom
# Aslam     11.333333
# Badr      11.166667
# Caroline  13.666667
# Chady      9.000000
# Eymen      8.000000
# Ismael     7.833333
# Micheal    8.666667
# Saleh      8.500000
# Sanaa      7.000000
# Soufiane  12.500000
# Younous   19.373333
# Youssef    9.833333

# %%
df.groupby("Prenom", as_index=False).agg({"Note": "mean"})
# Out:
#       Prenom       Note
# 0      Aslam  11.333333
# 1       Badr  11.166667
# 2   Caroline  13.666667
# 3      Chady   9.000000
# 4      Eymen   8.000000
# 5     Ismael   7.833333
# 6    Micheal   8.666667
# 7      Saleh   8.500000
# 8      Sanaa   7.000000
# 9   Soufiane  12.500000
# 10   Younous  19.373333
# 11   Youssef   9.833333

# %%
df.groupby("Matière", as_index=False).agg({"Note": "mean"})
# Out:
#            Matière       Note
# 0          Anglais   8.832500
# 1         Français   8.500000
# 2     Histoire-géo  12.041667
# 3            Maths  12.250000
# 4  Physique-Chimie  13.645833
# 5              SVT   8.166667

# %%
df.groupby("Matière", as_index=False).agg({"Note": "max"})
# Out:
#            Matière   Note
# 0          Anglais  19.99
# 1         Français  19.00
# 2     Histoire-géo  19.50
# 3            Maths  21.00
# 4  Physique-Chimie  20.00
# 5              SVT  20.00

# %%
df.groupby("Matière", as_index=False).agg({"Note": "min"})
# Out:
#            Matière  Note
# 0          Anglais   0.0
# 1         Français   1.0
# 2     Histoire-géo   3.0
# 3            Maths   3.0
# 4  Physique-Chimie   6.0
# 5              SVT   0.0

# %%
df.groupby("Prenom", as_index=False).agg({"Note": "max"})
# Out:
#       Prenom  Note
# 0      Aslam  19.0
# 1       Badr  20.0
# 2   Caroline  19.0
# 3      Chady  19.0
# 4      Eymen  20.0
# 5     Ismael  12.0
# 6    Micheal  17.0
# 7      Saleh  17.0
# 8      Sanaa  17.0
# 9   Soufiane  18.0
# 10   Younous  21.0
# 11   Youssef  20.0

# %%
df.groupby("Matière", as_index=False)["Note"].transform(max)
# Out:
#      Note
# 0   21.00
# 1   19.00
# 2   19.50
# 3   20.00
# 4   20.00
# ..    ...
# 67  19.00
# 68  19.50
# 69  20.00
# 70  20.00
# 71  19.99
#
# [72 rows x 1 columns]

# %%
df_m = df.copy()
df_m["NoteMaxMatière"] = df_m.groupby("Matière", as_index=False)["Note"].transform(max)
mask = df_m["Note"] == df_m["NoteMaxMatière"]
df_m[mask]
# Out:
#       Prenom          Matière   Note  NoteMaxMatière
# 1   Caroline         Français  19.00           19.00
# 22      Badr              SVT  20.00           20.00
# 39     Eymen  Physique-Chimie  20.00           20.00
# 66   Younous            Maths  21.00           21.00
# 67   Younous         Français  19.00           19.00
# 68   Younous     Histoire-géo  19.50           19.50
# 71   Younous          Anglais  19.99           19.99

# %%
df_p = df.copy()
df_p["NoteMaxEleve"] = df_p.groupby("Prenom", as_index=False)["Note"].transform(max)
mask = df_p["Note"] == df_p["NoteMaxEleve"]
df_p[mask]
# Out:
#       Prenom          Matière  Note  NoteMaxEleve
# 1   Caroline         Français  19.0          19.0
# 4   Caroline              SVT  19.0          19.0
# 6    Youssef            Maths  20.0          20.0
# 14   Micheal     Histoire-géo  17.0          17.0
# 22      Badr              SVT  20.0          20.0
# 26     Chady     Histoire-géo  19.0          19.0
# 31    Ismael         Français  12.0          12.0
# 32    Ismael     Histoire-géo  12.0          12.0
# 39     Eymen  Physique-Chimie  20.0          20.0
# 42     Aslam            Maths  19.0          19.0
# 48     Saleh            Maths  17.0          17.0
# 53     Saleh          Anglais  17.0          17.0
# 54  Soufiane            Maths  18.0          18.0
# 57  Soufiane  Physique-Chimie  18.0          18.0
# 63     Sanaa  Physique-Chimie  17.0          17.0
# 66   Younous            Maths  21.0          21.0

# %%
df_t = df.copy()
df_t["NoteMinEleve"] = df_t.groupby("Prenom", as_index=False)["Note"].transform(min)
mask = df_t["Note"] == df_t["NoteMinEleve"]
df_t[mask]
# Out:
#       Prenom          Matière   Note  NoteMinEleve
# 5   Caroline          Anglais   0.00          0.00
# 7    Youssef         Français   5.00          5.00
# 12   Micheal            Maths   3.00          3.00
# 19      Badr         Français   7.00          7.00
# 28     Chady              SVT   0.00          0.00
# 35    Ismael          Anglais   3.00          3.00
# 40     Eymen              SVT   0.00          0.00
# 44     Aslam     Histoire-géo   3.00          3.00
# 49     Saleh         Français   1.00          1.00
# 52     Saleh              SVT   1.00          1.00
# 58  Soufiane              SVT   2.00          2.00
# 64     Sanaa              SVT   1.00          1.00
# 69   Younous  Physique-Chimie  17.75         17.75

# %%
df_pivot = df.pivot_table(index="Prenom", columns="Matière", values="Note")
df_pivot
# Out:
# Matière   Anglais  Français  Histoire-géo  Maths  Physique-Chimie   SVT
# Prenom
# Aslam       10.00       8.0           3.0   19.0            16.00  12.0
# Badr        10.00       7.0           9.0   13.0             8.00  20.0
# Caroline     0.00      19.0          18.0    8.0            18.00  19.0
# Chady        3.00      12.0          19.0    4.0            16.00   0.0
# Eymen        2.00       4.0           8.0   14.0            20.00   0.0
# Ismael       3.00      12.0          12.0    4.0             8.00   8.0
# Micheal     11.00       5.0          17.0    3.0            11.00   5.0
# Saleh       17.00       1.0           7.0   17.0             8.00   1.0
# Sanaa        3.00       3.0          12.0    6.0            17.00   1.0
# Soufiane    17.00       7.0          13.0   18.0            18.00   2.0
# Younous     19.99      19.0          19.5   21.0            17.75  19.0
# Youssef     10.00       5.0           7.0   20.0             6.00  11.0

# %%
df_pivot.index.name = None
df_pivot.columns.name = None
df_pivot
# Out:
#           Anglais  Français  Histoire-géo  Maths  Physique-Chimie   SVT
# Aslam       10.00       8.0           3.0   19.0            16.00  12.0
# Badr        10.00       7.0           9.0   13.0             8.00  20.0
# Caroline     0.00      19.0          18.0    8.0            18.00  19.0
# Chady        3.00      12.0          19.0    4.0            16.00   0.0
# Eymen        2.00       4.0           8.0   14.0            20.00   0.0
# Ismael       3.00      12.0          12.0    4.0             8.00   8.0
# Micheal     11.00       5.0          17.0    3.0            11.00   5.0
# Saleh       17.00       1.0           7.0   17.0             8.00   1.0
# Sanaa        3.00       3.0          12.0    6.0            17.00   1.0
# Soufiane    17.00       7.0          13.0   18.0            18.00   2.0
# Younous     19.99      19.0          19.5   21.0            17.75  19.0
# Youssef     10.00       5.0           7.0   20.0             6.00  11.0

# %% [markdown]
# # Chapitre 3 : Distribution normale

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = random.normal(loc=13,scale=1, size=100)
plt.figure(figsize=(15, 10))
sns.histplot(data, kde=True, bins=15)
plt.show()
print(data.mean())
print(data.std())
# Out:
# 12.887194961684585
# 1.0807811417676625

# %%
sns.distplot(random.normal(size=1000), hist=False)

plt.show()
# Out:
# /home/younous/.local/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
